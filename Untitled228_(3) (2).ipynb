# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-56749d77-f846-4997-90fa-bfee761cf90e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56749d77-f846-4997-90fa-bfee761cf90e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('tons.csv')

# %%
df.head(5)
# Out:
#            ts         src_ip  src_port         dst_ip  dst_port proto service  \
# 0  1554198358    3.122.49.24      1883  192.168.1.152     52976   tcp       -
# 1  1554198358   192.168.1.79     47260  192.168.1.255     15600   udp       -
# 2  1554198359  192.168.1.152      1880  192.168.1.152     51782   tcp       -
# 3  1554198359  192.168.1.152     34296  192.168.1.152     10502   tcp       -
# 4  1554198362  192.168.1.152     46608  192.168.1.190        53   udp     dns
#
#        duration  src_bytes  dst_bytes  ... http_version  \
# 0  80549.530260    1762852   41933215  ...            -
# 1      0.000000          0          0  ...            -
# 2      0.000000          0          0  ...            -
# 3      0.000000          0          0  ...            -
# 4      0.000549          0        298  ...            -
#
#    http_request_body_len  http_response_body_len  http_status_code  \
# 0                      0                       0                 0
# ...

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()
def normalization(df,col):
  for i in col:
    arr = df[i]
    arr = np.array(arr)
    df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
  return df

# %%
df.head()
# Out:
#            ts         src_ip  src_port         dst_ip  dst_port proto service  \
# 0  1554198358    3.122.49.24      1883  192.168.1.152     52976   tcp       -
# 1  1554198358   192.168.1.79     47260  192.168.1.255     15600   udp       -
# 2  1554198359  192.168.1.152      1880  192.168.1.152     51782   tcp       -
# 3  1554198359  192.168.1.152     34296  192.168.1.152     10502   tcp       -
# 4  1554198362  192.168.1.152     46608  192.168.1.190        53   udp     dns
#
#        duration  src_bytes  dst_bytes  ... http_version  \
# 0  80549.530260    1762852   41933215  ...            -
# 1      0.000000          0          0  ...            -
# 2      0.000000          0          0  ...            -
# 3      0.000000          0          0  ...            -
# 4      0.000549          0        298  ...            -
#
#    http_request_body_len  http_response_body_len  http_status_code  \
# 0                      0                       0                 0
# ...

# %%
numeric_col = df.select_dtypes(include='number').columns

# %%
df = normalization(df.copy(),numeric_col)

# %%
df.head()
# Out:
#          ts         src_ip  src_port         dst_ip  dst_port proto service  \
# 0 -1.506750    3.122.49.24 -2.027317  192.168.1.152  3.242815   tcp       -
# 1 -1.506750   192.168.1.79  0.429553  192.168.1.255  0.562304   udp       -
# 2 -1.506749  192.168.1.152 -2.027479  192.168.1.152  3.157185   tcp       -
# 3 -1.506749  192.168.1.152 -0.272363  192.168.1.152  0.196689   tcp       -
# 4 -1.506746  192.168.1.152  0.394252  192.168.1.190 -0.552687   udp     dns
#
#      duration  src_bytes  dst_bytes  ... http_version  http_request_body_len  \
# 0  175.708476   0.141872   3.428194  ...            -              -0.004603
# 1   -0.018486  -0.010455  -0.009813  ...            -              -0.004603
# 2   -0.018486  -0.010455  -0.009813  ...            -              -0.004603
# 3   -0.018486  -0.010455  -0.009813  ...            -              -0.004603
# 4   -0.018485  -0.010455  -0.009789  ...            -              -0.004603
#
# ...

# %%
df.head()
# Out:
#          ts         src_ip  src_port         dst_ip  dst_port proto service  \
# 0 -1.506750    3.122.49.24 -2.027317  192.168.1.152  3.242815   tcp       -
# 1 -1.506750   192.168.1.79  0.429553  192.168.1.255  0.562304   udp       -
# 2 -1.506749  192.168.1.152 -2.027479  192.168.1.152  3.157185   tcp       -
# 3 -1.506749  192.168.1.152 -0.272363  192.168.1.152  0.196689   tcp       -
# 4 -1.506746  192.168.1.152  0.394252  192.168.1.190 -0.552687   udp     dns
#
#      duration  src_bytes  dst_bytes  ... http_version  http_request_body_len  \
# 0  175.708476   0.141872   3.428194  ...            -              -0.004603
# 1   -0.018486  -0.010455  -0.009813  ...            -              -0.004603
# 2   -0.018486  -0.010455  -0.009813  ...            -              -0.004603
# 3   -0.018486  -0.010455  -0.009813  ...            -              -0.004603
# 4   -0.018485  -0.010455  -0.009789  ...            -              -0.004603
#
# ...

# %%
bin_label = pd.DataFrame(df.proto.map(lambda x:'tcp_traffic' if x=='tcp' else 'udp_traffic'))

# %%
bin_data = df.copy()
bin_data['type'] = bin_label

# %%
le3 = preprocessing.LabelEncoder()
enc_label = bin_label.apply(le3.fit_transform)
bin_data['typ'] = enc_label

# %%
le3.classes_
# Out:
# array(['tcp_traffic', 'udp_traffic'], dtype=object)

# %%
np.save("le3_classes.npy",le3.classes_,allow_pickle=True)

# %%
bin_data.head()
# Out:
#          ts         src_ip  src_port         dst_ip  dst_port proto service  \
# 0 -1.506750    3.122.49.24 -2.027317  192.168.1.152  3.242815   tcp       -
# 1 -1.506750   192.168.1.79  0.429553  192.168.1.255  0.562304   udp       -
# 2 -1.506749  192.168.1.152 -2.027479  192.168.1.152  3.157185   tcp       -
# 3 -1.506749  192.168.1.152 -0.272363  192.168.1.152  0.196689   tcp       -
# 4 -1.506746  192.168.1.152  0.394252  192.168.1.190 -0.552687   udp     dns
#
#      duration  src_bytes  dst_bytes  ... http_response_body_len  \
# 0  175.708476   0.141872   3.428194  ...              -0.003138
# 1   -0.018486  -0.010455  -0.009813  ...              -0.003138
# 2   -0.018486  -0.010455  -0.009813  ...              -0.003138
# 3   -0.018486  -0.010455  -0.009813  ...              -0.003138
# 4   -0.018485  -0.010455  -0.009789  ...              -0.003138
#
#    http_status_code  http_user_agent  http_orig_mime_types  \
# 0         -0.022316                -                     -
# ...

# %%
bin_data = pd.get_dummies(bin_data,columns=['type'],prefix="",prefix_sep="")
bin_data['type'] = bin_label
bin_data
# Out:
#               ts         src_ip  src_port         dst_ip  dst_port proto  \
# 0      -1.506750    3.122.49.24 -2.027317  192.168.1.152  3.242815   tcp
# 1      -1.506750   192.168.1.79  0.429553  192.168.1.255  0.562304   udp
# 2      -1.506749  192.168.1.152 -2.027479  192.168.1.152  3.157185   tcp
# 3      -1.506749  192.168.1.152 -0.272363  192.168.1.152  0.196689   tcp
# 4      -1.506746  192.168.1.152  0.394252  192.168.1.190 -0.552687   udp
# ...          ...            ...       ...            ...       ...   ...
# 461038  0.758239   192.168.1.32 -0.336686  176.28.50.165 -0.550750   tcp
# 461039  0.845485   192.168.1.33 -0.112856  34.230.157.88 -0.524717   tcp
# 461040  0.859453   192.168.1.37 -1.888655  192.168.1.193  2.970433   tcp
# 461041  0.969229   192.168.1.31  1.163523  104.98.29.100 -0.524717   tcp
# 461042  0.969229   192.168.1.31  0.093539  151.101.24.64 -0.524717   tcp
#
#        service    duration  src_bytes  dst_bytes  ... http_user_agent  \
# ...

# %%
numeric_bin = bin_data[numeric_col]
numeric_bin['typ'] = bin_data['typ']
# Out:
# <ipython-input-20-1b7f582b39ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_bin['typ'] = bin_data['typ']

# %%
corr= numeric_bin.corr()
corr_y = abs(corr['typ'])
highest_corr = corr_y[corr_y >0.2]
highest_corr.sort_values(ascending=True)
# Out:
# dns_rcode    0.203247
# dns_qtype    0.255290
# typ          1.000000
# Name: typ, dtype: float64

# %%
numeric_bin = bin_data[['dns_rcode','dns_qtype']]

# %%
#numeric_bin = numeric_bin.join(categorical)

bin_data = numeric_bin.join(bin_data[['typ']])

# %%
bin_data.to_csv('bin_data.csv', index=False)

bin_data
# Out:
#         dns_rcode  dns_qtype  typ
# 0       -0.161893  -0.203347    0
# 1       -0.161893  -0.203347    1
# 2       -0.161893  -0.203347    0
# 3       -0.161893  -0.203347    0
# 4       -0.161893  -0.203347    1
# ...           ...        ...  ...
# 461038  -0.161893  -0.203347    0
# 461039  -0.161893  -0.203347    0
# 461040  -0.161893  -0.203347    0
# 461041  -0.161893  -0.203347    0
# 461042  -0.161893  -0.203347    0
#
# [461043 rows x 3 columns]

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pickle
from os import path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bin_data = pd.read_csv('bin_data.csv')
bin_data.drop(bin_data.columns[0],axis=1,inplace=True)


le2_classes_ = np.load('le3_classes.npy',allow_pickle=True)

# %%
X = bin_data.iloc[:,0:3].to_numpy()
Y = bin_data['typ']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.30, random_state=42)

# %%
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

# %%
sel = SelectFromModel(RandomForestClassifier())
sel.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
import xgboost as xgb

# Create regression matrices
dtrain_reg = xgb.DMatrix(X_train, y_train, enable_categorical=True)
dtest_reg = xgb.DMatrix(X_test, y_test, enable_categorical=True)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred,target_names=le2_classes_))
# Out:
#               precision    recall  f1-score   support
#
#  tcp_traffic       1.00      1.00      1.00     84506
#  udp_traffic       1.00      1.00      1.00     53807
#
#     accuracy                           1.00    138313
#    macro avg       1.00      1.00      1.00    138313
# weighted avg       1.00      1.00      1.00    138313

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,auc
ll_tpr,ll_fpr,threshold=roc_curve(y_test,y_pred)
auc_ll=auc(ll_tpr,ll_fpr)
plt.figure(figsize=(4,4),dpi=100)
plt.plot(ll_tpr,ll_fpr ,marker='.',label='Proposed Model(auc=%0.3f)'%auc_ll)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.legend()
plt.show()
